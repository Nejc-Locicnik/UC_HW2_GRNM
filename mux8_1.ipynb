# %%
from grenmlin import simulator, grn
import numpy as np
import matplotlib.pyplot as plt
from helper_functions import visualize, get_input_signals, test_inputs

# %% [markdown]
# ## 8:1 MUX

# %%
my_grn = grn.grn()
# 6 input species
my_grn.add_input_species("X1")
my_grn.add_input_species("X2")
my_grn.add_input_species("X3")
my_grn.add_input_species("X4")
my_grn.add_input_species("X5")
my_grn.add_input_species("X6")
my_grn.add_input_species("X7")
my_grn.add_input_species("X8")
my_grn.add_input_species("S1")
my_grn.add_input_species("S2")
my_grn.add_input_species("S3")

# 1 output species
my_grn.add_species("MUX", 0.1)

# %%
# X1 AND NOT S1 AND NOT S2 AND NOT S3
regulators = [{'name': 'X1', 'type': 1, 'Kd': 5, 'n': 2},
              {'name': 'S1', 'type': -1, 'Kd': 5, 'n': 3},
              {'name': 'S2', 'type': -1, 'Kd': 5, 'n': 3},
              {'name': 'S3', 'type': -1, 'Kd': 5, 'n': 3}]
products = [{'name': 'MUX'}]
my_grn.add_gene(10, regulators, products)

# X2 AND S1 AND NOT S2 AND NOT S3
regulators = [{'name': 'X2', 'type': 1, 'Kd': 5, 'n': 2},
              {'name': 'S1', 'type': 1, 'Kd': 5, 'n': 3},
              {'name': 'S2', 'type': -1, 'Kd': 5, 'n': 3},
              {'name': 'S3', 'type': -1, 'Kd': 5, 'n': 3}]
products = [{'name': 'MUX'}]
my_grn.add_gene(10, regulators, products)

# X3 AND NOT S1 AND S2 AND NOT S3
regulators = [{'name': 'X3', 'type': 1, 'Kd': 5, 'n': 2},
              {'name': 'S1', 'type': -1, 'Kd': 5, 'n': 3},
              {'name': 'S2', 'type': 1, 'Kd': 5, 'n': 3},
              {'name': 'S3', 'type': -1, 'Kd': 5, 'n': 3}]
products = [{'name': 'MUX'}]
my_grn.add_gene(10, regulators, products)

# X4 AND S1 AND S2 AND NOT S3
regulators = [{'name': 'X4', 'type': 1, 'Kd': 5, 'n': 2},
              {'name': 'S1', 'type': 1, 'Kd': 5, 'n': 3},
              {'name': 'S2', 'type': 1, 'Kd': 5, 'n': 3},
              {'name': 'S3', 'type': -1, 'Kd': 5, 'n': 3}]
products = [{'name': 'MUX'}]
my_grn.add_gene(10, regulators, products)

# X5 AND NOT S1 AND NOT S2 AND S3
regulators = [{'name': 'X5', 'type': 1, 'Kd': 5, 'n': 2},
              {'name': 'S1', 'type': -1, 'Kd': 5, 'n': 3},
              {'name': 'S2', 'type': -1, 'Kd': 5, 'n': 3},
              {'name': 'S3', 'type': 1, 'Kd': 5, 'n': 3}]
products = [{'name': 'MUX'}]
my_grn.add_gene(10, regulators, products)

# X6 AND S1 AND NOT S2 AND S3
regulators = [{'name': 'X6', 'type': 1, 'Kd': 5, 'n': 2},
              {'name': 'S1', 'type': 1, 'Kd': 5, 'n': 3},
              {'name': 'S2', 'type': -1, 'Kd': 5, 'n': 3},
              {'name': 'S3', 'type': 1, 'Kd': 5, 'n': 3}]
products = [{'name': 'MUX'}]
my_grn.add_gene(10, regulators, products)

# X7 AND NOT S1 AND S2 AND S3
regulators = [{'name': 'X7', 'type': 1, 'Kd': 5, 'n': 2},
              {'name': 'S1', 'type': -1, 'Kd': 5, 'n': 3},
              {'name': 'S2', 'type': 1, 'Kd': 5, 'n': 3},
              {'name': 'S3', 'type': 1, 'Kd': 5, 'n': 3}]
products = [{'name': 'MUX'}]
my_grn.add_gene(10, regulators, products)

# X8 AND S1 AND S2 AND S3
regulators = [{'name': 'X8', 'type': 1, 'Kd': 5, 'n': 2},
              {'name': 'S1', 'type': 1, 'Kd': 5, 'n': 3},
              {'name': 'S2', 'type': 1, 'Kd': 5, 'n': 3},
              {'name': 'S3', 'type': 1, 'Kd': 5, 'n': 3}]
products = [{'name': 'MUX'}]
my_grn.add_gene(10, regulators, products)

# %%
my_grn.plot_network()

# %%
inputs = get_input_signals(11, 100)
T, Y = simulator.simulate_sequence(my_grn, inputs, t_single = 250, plot_on=False, model="models/8_1_mux_model")

# %%
visualize(T, Y, my_grn)
# Out:
# /home/anzearhar/dev/faks/npmp/UC_HW2_GRNM/helper_functions.py:21: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
